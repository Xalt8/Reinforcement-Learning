# %% [markdown]
# # Reinforcement learning using OpenAI Gym and DQN using Pytorch
# *Source code: https://www.youtube.com/watch?v=PyQNfsGUnQA&list=PLZbbT5o_s2xoWNVdDudn51XM8lOuZ_Njv&index=16&ab_channel=deeplizard*

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image 
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %% [markdown]
# ## Setup display

# %%
is_python = 'inline' in matplotlib.get_backend()
if is_python: from IPython import display
# %matplotlib inline

# %% [markdown]
# ## Deep Q-Network

# %%
class DQN(nn.Module):
    
    def __init__(self, img_height, img_width):
        super().__init__()

        self.fc1 = nn.Linear(in_features=img_height*img_width*3, out_features=24)
        self.fc2 = nn.Linear(in_features=24, out_features=32)
        self.out = nn.Linear(in_features=32, out_features=2)

    def forward(self, t): # images tensor 't' 
        t = t.flatten(start_dim = 1) # gets flattended
        t = F.relu(self.fc1(t)) # Gets passed to the first layer and gets relu applied to it
        t = F.relu(self.fc2(t)) # Gets passed to the second layer and gets relu applied to it
        t = self.out(t) # output layer
        return t

# %% [markdown]
# ## Experience class
#
# Experiences from replay memory will be used to train the network

# %%
Experiences = namedtuple('Experience', 
                        ('state', 'action', 'next_state', 'reward')
                        )

# %%
e = Experiences(2,3,1,4)
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7f557fee4aff> in <module>
# ----> 1 e = Experiences(2,3,1,4)
#       2 e
#
# NameError: name 'Experiences' is not defined

# %% [markdown]
# ## Replay Memory

# %%
class ReplayMemory():
    def __init__(self, capacity):
        self.capacity = capacity # The limited capacity of the replay memory
        self.memory = [] # Will be used to store the experiences
        self.push_count = 0 # Use this to keep count of how many experiences we have added to memory

    def push(self, experience): # Method used to store memories as they occur
        if len(self.memory) < self.capacity: # Before pushing a memory we need to check the memory is less than capacity
            self.memory.append(experience)
        else:
            # If we're out of memory we push the new experiences to the front of memory overiding the older experiences
            self.memory[self.push_count % self.capacity] = experience 
        self.push_count += 1

    def sample(self, batch_size):
        ''' These samples will be used to train the DQN
            Returns a random sample of experiences
            The number of randomly sampled experiences = batch_size'''
        return random.sample(self.memory, batch_size)

    def can_provide_sample(self, batch_size):
        ''' Returns a boolean value -> if we can provide a sample from memory'''
        return len(self.memory) >= batch_size

# %% [markdown]
# ## Epsilon Greedy Strategy

# %%
class EpsilonGreedyStrategy():
    def __init__(self, start, end, decay):
        self.start = start
        self.end = end
        self.decay = decay

    def get_exploration_rate(self, current_step):
        return self.end + (self.start - self.end) * \
            math.exp(-1 * current_step * self.decay)

# %% [markdown]
# ## Reinforcement Learning Agent

# %%
class Agent():
    def __init__(self, strategy, num_actions, device):
        ''' strategy will use the EpsilonGreedyStrategy to get strategy
            num_actions: how many actions the agent can take from a given state (2) left/right
            current_step: the current step in the environment
        '''
        self.current_step = 0
        self.strategy = strategy
        self.num_actions = num_actions
        self.device = device

    def select_action(self, state, policy_net):
        ''' The policy_net is the DQN that will learn the optimal policy
            rate: will return the get_exploration_rate() from EpsilonGreedyStrategy class
        '''
        rate = strategy.get_exploration_rate(self.current_step)
        self.current_step += 1

        if rate > random.random(): # if the rate retured is greater than randomly generated num -> explore 
            action =  random.randrange(self.num_actions) # explore 
            return torch.tensor([action]).to(device)
        else: # if the rate is not greater than rand num -> get the highest value generated from policy net 
            with torch.no_grad(): # Turning off gradient tracking because we are using the model for inference and not training
                return policy_net(state).argmax(dim=1).to(device) # exploit

# %% [markdown]
# ## Environment Manager

# %%
class CartPoleEnvManager():
    def __init__(self, device):
        self.device = device
        self.env = gym.make('CartPole-v0').unwrapped
        self.env.reset()
        self.current_screen = None
        self.done = None

    def reset(self):
        self.env.reset()
        self.current_screen = None

    def close(self):
        self.env.close()

    def render(self, mode='human'):
        return self.env.render(mode)

    def num_actions_available(self):
        return self.env.action_space.n
    
    def take_action(self, action):
        _, reward, self.done, _ = self.env.step(action.item())
        return torch.tensor([reward], device=self.device)

    def just_starting(self):
        return self.current_screen is None

    def get_state(self):
        if self.just_starting() or self.done:
            self.current_screen = self.get_processed_screen()
            black_screen = torch.zeros_like(self.current_screen)
            return black_screen
        else:
            s1 = self.current_screen
            s2 = self.get_processed_screen()
            self.current_screen = s2
            return s2 - s1
    
    def get_screen_height(self):
        screen = self.get_processed_screen()
        return screen.shape[2]

    def get_screen_width(self):
        screen = self.get_processed_screen()
        return screen.shape[3]

    def get_processed_screen(self):
        screen = self.render('rgb_array').transpose((2,0,1))
        screen = self.crop_screen(screen)
        return self.transform_screen_data(screen)
    
    def crop_screen(self, screen):
        screen_height = screen.shape[1]
        #Strip off top and bottom
        top = int(screen_height * 0.4)
        bottom = int(screen_height * 0.8)
        screen = screen[:, top:bottom, :]
        return screen
    
    def transform_screen_data(self, screen):
        screen = np.ascontiguousarray(screen, dtype=np.float32)/255
        screen = torch.from_numpy(screen)

        resize = T.Compose([
            T.ToPILImage(),
            T.Resize((40,90)),
            T.ToTensor()
        ])
        return resize(screen).unsqueeze(0).to(self.device)

# %% [markdown]
# ## Tensor processing

# %%
def extract_tensors(experiences):

    batch = Experiences(*zip(*experiences))

    t1.torch.cat(batch.state)
    t2.torch.cat(batch.action)
    t3.torch.cat(batch.reward)
    t4.torch.cat(batch.next_state)

    return (t1,t2,t3,t4)

# %% [markdown]
# ## Q-Value Calculator

# %%
class QValue():
    device = torch.device('cpu')

    @staticmethod
    def get_current(policy_net, states, actions):
        return policy_net(states).gather(dim=1, index=actions.unsqeeze(-1))

    @staticmethod
    def get_next(target_net, next_states):
        final_state_locations = next_states.flatten(start_dim=1).max(dim=1)[0].eq(0).type(torch.bool)
        non_final_state_locations = (final_state_locations == False)
        non_final_states = next_states[non_final_state_locations]
        batch_size = next_states.shape[0]
        values = torch.zeros(batch_size).to(QValue.device)
        values[non_final_state_locations] - target_net(non_final_states).max(dim=1)[0].detach()
        return values

# %%
# device = ('cpu')
# em = CartPoleEnvManager(device)
# em.reset()
# screen = em.render('rgb_array')

# plt.figure()
# plt.imshow(screen)
# plt.title('Non-processed screen example')
# plt.show()

# %% [markdown]
# Example of processed screen

# %%
# screen = em.get_processed_screen()
# plt.figure()
# plt.imshow(screen)
# plt.title('Processed screen example')
# plt.show()

# %%
def plot(values, moving_avg_period):
    plt.figure(2)
    plt.clf()
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(values)

    moving_avg = get_moving_average(moving_avg_period, values)
    plt.plot(moving_avg)
    plt.pause(0.001)
    print("Episodes", len(values), '\n', moving_avg_period, 'episodes moving avg:', moving_avg[-1])
    if is_python: display.clear_output(wait=True)

def get_moving_average(period, values):
    values = torch.tensor(values, dtype=torch.float)
    if len(values)>= period:
        moving_avg = values.unfold(dimension=0, size=period, step=1).mean(dim=1).flatten(start_dim=0)
        moving_avg = torch.cat((torch.zeros(period-1), moving_avg))
        return moving_avg.numpy()
    else:
        moving_avg = torch.zeros(len(values))
        return moving_avg.numpy()

# %%
plot(np.random.rand(300),100)
# Out:
# Episodes 300
#  100 episodes moving avg: 0.4810777

# %% [markdown]
# ## Main program

# %%
batch_size = 256
gamma = 0.999 # Discount factor
eps_start = 1
eps_end = 0.01
eps_decay = 0.001
target_update = 10 # How frequenty the traget networks' weights will be updated by policy network's weights
memory_size = 100000
lr = 0.001
num_episodes = 1000

device = 'cpu'
em = CartPoleEnvManager(device)
strategy = EpsilonGreedyStrategy(eps_start, eps_end, eps_decay)
agent = Agent(strategy, em.num_actions_available(), device)
memory = ReplayMemory(memory_size)

policy_net = DQN(em.get_screen_height(), em.get_screen_width()).to(device)
target_net = DQN(em.get_screen_height(), em.get_screen_width()).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(params=policy_net.parameters(), lr=lr)

# %%
episode_durations = []
for episode in range(num_episodes):
    em.reset()
    state = em.get_state()

    for timestep in count():
        action = agent.select_action(state, policy_net)
        reward = em.take_action(action)
        next_state = em.get_state()
        memory.push(Experience(state, action, next_state, reward))
        state = next_state

        if memory.can_provide_sample(batch_size):
            experiences = memory.sample(batch_size)
            states, actions, rewards, next_state = extract_tensors(experiences)

            current_q_values = QValues.get_current(policy_net, states, actions)
            next_q_values = QValues.get_next(target_net, next_states)
            target_q_values = (next_q_values * gamma) + rewards

            loss = F.mse_loss(current_q_values, target_q_values.unsqeeze(1))
            optimiser.zero_grad()
            loss.backward()
            optimiser.step()
        
        if em.done:
            episode_durations.append(timestep)
            plot(episode_durations, 100)
            break
    
    if episode % target_update ==0:
        target_net.load_state_dict(policy_net.state_dict())

em.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-770b2d2a20ed> in <module>
#       1 episode_durations = []
# ----> 2 for episode in range(num_episodes):
#       3     em.reset()
#       4     state = em.get_state()
#       5
#
# NameError: name 'num_episodes' is not defined
